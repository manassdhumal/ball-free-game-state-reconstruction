# %% [markdown]
# # Robustness Statistical Validation (Step 74)
#
# This notebook loads the machine-readable results produced by
# the experiment runner and produces the figures described in
# the project roadmap and docs. Run this after the experiment outputs
# exist under `results/metrics/robustness_expansion` and `results/runs/robustness_expansion`.

# %%
import pandas as pd
import pathlib
from matplotlib import pyplot as plt

metrics_dir = pathlib.Path('results/metrics/robustness_expansion')
summary_files = list(metrics_dir.glob('*_summary.csv'))
dfs = [pd.read_csv(p) for p in summary_files]
summary = pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()
summary.head()
